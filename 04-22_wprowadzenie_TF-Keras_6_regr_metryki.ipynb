836,-4.395745940641703,-3.5712994249300323,-2.267266973815822,2.02763035033189,-1.7772392794756087,-2.3617437866840305,-6.172393206819024,-2.016342103835939,-8.607267200257894,3.575995638321942,-2.07484509843448,-6.485301677463852,-9.603931656042917,14.440424493231447,-2.98975607242447,12.5162900381304,9.030230484914739,-15.467311494478722,-3.286217708386573,-18.796426140174418,-1.026091013152751,3.8916702003839845,12.711537477883255,-6.015782235409034,-10.427593064189892,11.376784159506713,10.676514116095973,3.1737744202459055,1.2862670937515333,-1.268806071038341,-5.358564566223379,-5.328691204506157,21.414819587711804,3.2657741668373035,11.78430993426673,19.78106847175799,6.3211450414208485,12.45520209827177,8.438686753780104,-1.8231151879908793,-1.496216485668242,-5.679541236706086,9.323350877056583,6.275813239547432,4.267321437829239,-1.7622593064650545,-21.76088122599853,1.1191082347971815,-16.65580695269773,-7.097282729935472,-6.930062262439833,4.066270201935978,7.63804526080294,4.076756674741688,-1.5154128185099296,0.601761878462554,4.1199657326287,-12.23508298569358,11.375620487797136,3.026664045826166,7.126962074900575,-3.06538525290145,-8.328352029484279,-8.927216054445239,9.474879469728677,-6.115868030330887,0.15033250628101769,11.375687366508032,-19.086177834085063,3.1804863724690975,0.5672831016936897,-4.125318610276935,-7.881451159722872,4.831896696284062,-0.033413394749260306,-13.773993506664944,4.156129334940772,-6.274947060549081,-13.378776979239305,-2.009827042713667,-16.43675371680277,4.281975881075937,7.4607432322100635,-1.8947678630945717,-1.8503978493536835,-0.4514368289953836,6.00790622615645,10.348930096917883,22.832203672004027,6.319495069970245,8.201483415788516,-11.339704070851298,9.370287857760204,-10.707211411068045,0.40543627392720794,-13.353884553300873,-2.0326071826891763,-2.59039228300972,8.89205205664257,-10.323092693997381,-0.9238892665858316,3.6809464454582894,-10.1 ...

# %%
def mean_absolute_error(y_true, y_pred):
    return abs(y_true - y_pred).sum() / len(y_true)

mean_absolute_error(y_true, y_pred)
# Out:
# 7.854319874456425

# %%
from tensorflow.keras.losses import mean_absolute_error
mean_absolute_error(y_true, y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=7.854319874456425>

# %%
def mean_squared_error(y_true, y_pred):
  return ((y_true-y_pred)**2).sum() / len(y_true)

# %%
mean_squared_error(y_true, y_pred)
# Out:
# 97.82362758601397

# %%
def root_mean_squared_error(y_true, y_pred):
    return np.sqrt(((y_true - y_pred) ** 2).sum() / len(y_true))

root_mean_squared_error(y_true, y_pred)
# Out:
# 9.890582772820515

# %%
def max_error(y_true, y_pred):
    return abs(y_true - y_pred).max()

# %%
max_error(y_true, y_pred)
# Out:
# 34.497998353899106

# %%
from sklearn.metrics import max_error

max_error(y_true, y_pred)
# Out:
# 34.497998353899106

# %%
from sklearn.metrics import r2_score

r2_score(y_true, y_pred)
# Out:
# 0.7354372238722134

# %%
def r2_score(y_true, y_pred):
    numerator = ((y_true - y_pred) ** 2).sum()
    denominator = ((y_true - y_true.mean()) ** 2).sum()
    try:
        r2 = 1 - numerator / denominator
    except ZeroDivisionError:
        print('Dzielenie przez zero')
    return r2

# %%
r2_score(y_true, y_pred)
# Out:
# 0.7354372238722134
